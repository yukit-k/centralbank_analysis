# %%
import numpy as np
import pandas as pd
import datetime as dt
import os
import codecs

import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

import re
import pickle

import nltk

# %%
file = open('../data/FOMC/statements.pickle', 'rb')

statements = pickle.load(file)

file.close()

statements
# Out:
#                                                    statements
# 1994-02-04  Chairman Alan Greenspan announced today that t...
# 1994-03-22  Chairman Alan Greenspan announced today that t...
# 1994-04-18  Chairman Alan Greenspan announced today that t...
# 1994-05-17  The Federal Reserve today announced two action...
# 1994-08-16  The Federal Reserve announced today the follow...
# ...                                                       ...
# 2019-09-18  The Federal Reserve, the central bank of the U...
# 2019-10-11  The Federal Reserve, the central bank of the U...
# 2019-10-30  The Federal Reserve, the central bank of the U...
# 2019-12-11  The Federal Reserve, the central bank of the U...
# 2020-01-29  The Federal Reserve, the central bank of the U...
#
# [191 rows x 1 columns]
